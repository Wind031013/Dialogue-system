# %%
import re
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
        'X-Requested-With': 'XMLHttpRequest'
    }

# %%
# 获取网页内容
def get_html(url):
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.encoding = 'utf-8'
        response.raise_for_status()  # 检查请求是否成功
        return response.text
    except requests.RequestException as e:
        print(f"请求失败: {url}, 错误信息: {e}")
        return None

# %%
#保存文本到文件
def save_to_file(save_path, lines):
    try:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, 'w', encoding='utf-8') as f:
            for line in lines:
                f.write(line + '\n')
        print(f"成功保存到: {save_path}")
    except Exception as e:
        print(f"文件保存失败: {save_path}, 错误信息: {e}")

# %%
def extract_chapter_title(soup):
    bookname_div = soup.find('div', class_='bookname')
    if bookname_div:
        title_tag = bookname_div.find('h1')
        if title_tag:
            return title_tag.get_text(strip=True)
        
    return None

# %%
def get_next_page(soup, base_url):
    next_link_tag = soup.find('a', string = re.compile('下一章'))
    if next_link_tag:
        href = next_link_tag.get('href')
    if href:
        return urljoin(base_url, href)

# %%
def crawler(crawler_url, save_path, chapter_num):
    html_content = get_html(crawler_url)
    if not html_content:
        return None
    
    try:
        soup = BeautifulSoup(get_html(crawler_url), 'html.parser')
        
        content_div = soup.find('div', class_='content')
        if not content_div:
            print(f"未找到内容区域: {crawler_url}")
            return None
        # 获取标题名
        chapter_title = extract_chapter_title(soup)
        print(f"正在爬取第 {chapter_num} 章: {chapter_title}")
        # 处理内容
        lines = [chapter_title, " "] 
        content_lines = [line.strip() for line in content_div.get_text().split('\n') if line.strip()]
        lines.extend(content_lines)
        # 保存到文件
        save_to_file(save_path, lines)
        # 返回下一章URL
        return get_next_page(soup, crawler_url)
    except Exception as e:
        print(f"解析失败: {crawler_url}, 错误信息: {e}")
        return None

# %%
if __name__ == "__main__":
    start_url = "http://www.biqugewx.info/biquge/25300/55819903"
    save_dir = r"E:\论文\代码\数据处理\data"
    
    current_url = start_url
    chapter_count = 1573
    max_chapters = 1623
    
    while current_url and chapter_count <= max_chapters:
        save_path = os.path.join(save_dir, f"data_{chapter_count}.txt")
        print(f"正在爬取第 {chapter_count} 章, URL: {current_url}")
        
        next_url = crawler(current_url, save_path, chapter_count)
        current_url = next_url
        chapter_count += 1
        
        import time
        time.sleep(0.5)
    
    print("爬取完成！")
# Out:
# 正在爬取第 1573 章, URL: http://www.biqugewx.info/biquge/25300/55819903
# 正在爬取第 1573 章: VIP卷 第一千五百七十三章   本源帝气
# 成功保存到: E:\论文\代码\数据处理\data\data_1573.txt
# 正在爬取第 1574 章, URL: http://www.biqugewx.info/biquge/25300/55819904
# 正在爬取第 1574 章: VIP卷 第一千五百七十四章  天墓之魂
# 成功保存到: E:\论文\代码\数据处理\data\data_1574.txt
# 正在爬取第 1575 章, URL: http://www.biqugewx.info/biquge/25300/55819905
# 正在爬取第 1575 章: VIP卷 第一千五百七十五章    抽取灵魂本源
# 成功保存到: E:\论文\代码\数据处理\data\data_1575.txt
# 正在爬取第 1576 章, URL: http://www.biqugewx.info/biquge/25300/55819906
# 正在爬取第 1576 章: VIP卷 第一千五百七十六章   帝境灵魂
# 成功保存到: E:\论文\代码\数据处理\data\data_1576.txt
# 正在爬取第 1577 章, URL: http://www.biqugewx.info/biquge/25300/55819907
# 正在爬取第 1577 章: VIP卷 第一千五百七十七章   出天墓
# 成功保存到: E:\论文\代码\数据处理\data\data_1577.txt
# 正在爬取第 1578 章, URL: http://www.biqugewx.info/biquge/25300/55819908
# 正在爬取第 1578 章: VIP卷 第一千五百七十八章    大战前夕
# 成功保存到: E:\论文\代码\数据处理\data\data_1578.txt
# 正在爬取第 1579 章, URL: http://www.biqugewx.info/biquge/25300/55819909
# 正在爬取第 1579 章: VIP卷 第一千五百七十九章    大军出动
# 成功保存到: E:\论文\代码\数据处理\data\data_1579.txt
# 正在爬取第 1580 章, URL: http://www.biqugewx.info/biquge/25300/55819910
# 正在爬取第 1580 章: VIP卷 第一千五百八十章   葬天山脉
# 成功保存到: E:\论文\代码\数据处理\data\data_1580.txt
# 正在爬取第 1581 章, URL: http://www.biqugewx.info/biquge/25300/55819911
# 正在爬取第 1581 章: VIP卷 第一千五百八十一章   父子相见（明天请一天假）
# 成功保存到: E:\论文\代码\数据处理\data\data_1581.txt
# 正在爬取第 1582 章, URL: http://www.biqugewx.info/biquge/25300/55819912
# 正在爬取第 1582 章: VIP卷 第一千五百八十二章    大战
# 成功保存到: E:\论文\代码\数据处理\data\data_1582.txt
# 正在爬取第 1583 章, URL: http://www.biqugewx.info/biquge/25300/55819913
# 正在爬取第 1583 章: VIP卷 第一千五百八十三章   魂元天
# 成功保存到: E:\论文\代码\数据处理\data\data_1583.txt
# 正在爬取第 1584 章, URL: http://www.biqugewx.info/biquge/25300/55819914
# 正在爬取第 1584 章: VIP卷 第一千五百八十四章 死寂之门
# 成功保存到: E:\论文\代码\数据处理\data\data_1584.txt
# 正在爬取第 1585 章, URL: http://www.biqugewx.info/biquge/25300/55819915
# 正在爬取第 1585 章: VIP卷 第一千五百八十五章   据为己有
# 成功保存到: E:\论文\代码\数据处理\data\data_1585.txt
# 正在爬取第 1586 章, URL: http://www.biqugewx.info/biquge/25300/55819916
# 正在爬取第 1586 章: VIP卷 第一千五百八十六章   破界
# 成功保存到: E:\论文\代码\数据处理\data\data_1586.txt
# 正在爬取第 1587 章, URL: http://www.biqugewx.info/biquge/25300/55819917
# 正在爬取第 1587 章: VIP卷 第一千五百八十七章   退走
# 成功保存到: E:\论文\代码\数据处理\data\data_1587.txt
# 正在爬取第 1588 章, URL: http://www.biqugewx.info/biquge/25300/55819918
# 正在爬取第 1588 章: VIP卷 第一千五百八十八章   定计
# 成功保存到: E:\论文\代码\数据处理\data\data_1588.txt
# 正在爬取第 1589 章, URL: http://www.biqugewx.info/biquge/25300/55819919
# 正在爬取第 1589 章: VIP卷 第一千五百八十九章  宁静
# 成功保存到: E:\论文\代码\数据处理\data\data_1589.txt
# 正在爬取第 1590 章, URL: http://www.biqugewx.info/biquge/25300/55819920
# 正在爬取第 1590 章: VIP卷 第一千五百九十章   雷劫丹
# 成功保存到: E:\论文\代码\数据处理\data\data_1590.txt
# 正在爬取第 1591 章, URL: http://www.biqugewx.info/biquge/25300/55819921
# 正在爬取第 1591 章: VIP卷 第一千五百九十一章 七星斗圣
# 成功保存到: E:\论文\代码\数据处理\data\data_1591.txt
# 正在爬取第 1592 章, URL: http://www.biqugewx.info/biquge/25300/55819922
# 正在爬取第 1592 章: VIP卷 第一千五百九十二章  探测古帝洞府
# 成功保存到: E:\论文\代码\数据处理\data\data_1592.txt
# 正在爬取第 1593 章, URL: http://www.biqugewx.info/biquge/25300/55819923
# 正在爬取第 1593 章: VIP卷 第一千五百九十三章    古帝洞府所在（此章免费！）
# 成功保存到: E:\论文\代码\数据处理\data\data_1593.txt
# 正在爬取第 1594 章, URL: http://www.biqugewx.info/biquge/25300/55819924
# 正在爬取第 1594 章: VIP卷 第一千五百九十三章 古帝洞府所在
# 成功保存到: E:\论文\代码\数据处理\data\data_1594.txt
# 正在爬取第 1595 章, URL: http://www.biqugewx.info/biquge/25300/55819925
# 正在爬取第 1595 章: VIP卷 第一千五百九十四章  黑角域之难
# 成功保存到: E:\论文\代码\数据处理\data\data_1595.txt
# 正在爬取第 1596 章, URL: http://www.biqugewx.info/biquge/25300/55819926
# 正在爬取第 1596 章: VIP卷 第一千五百九十五章  赶至
# 成功保存到: E:\论文\代码\数据处理\data\data_1596.txt
# 正在爬取第 1597 章, URL: http://www.biqugewx.info/biquge/25300/55819927
# 正在爬取第 1597 章: VIP卷 第一千五百九十六章 故人再见
# 成功保存到: E:\论文\代码\数据处理\data\data_1597.txt
# 正在爬取第 1598 章, URL: http://www.biqugewx.info/biquge/25300/55819928
# 正在爬取第 1598 章: VIP卷 第一千五百九十七章   再入岩浆世界
# 成功保存到: E:\论文\代码\数据处理\data\data_1598.txt
# 正在爬取第 1599 章, URL: http://www.biqugewx.info/biquge/25300/55819929
# 正在爬取第 1599 章: VIP卷 第一千五百九十八章  岩浆之底的空间
# 成功保存到: E:\论文\代码\数据处理\data\data_1599.txt
# 正在爬取第 1600 章, URL: http://www.biqugewx.info/biquge/25300/55819930
# 正在爬取第 1600 章: VIP卷 第一千五百九十九章   神秘生物
# 成功保存到: E:\论文\代码\数据处理\data\data_1600.txt
# 正在爬取第 1601 章, URL: http://www.biqugewx.info/biquge/25300/55819931
# 正在爬取第 1601 章: VIP卷 第一千六百章  对话
# 成功保存到: E:\论文\代码\数据处理\data\data_1601.txt
# 正在爬取第 1602 章, URL: http://www.biqugewx.info/biquge/25300/55819932
# 正在爬取第 1602 章: VIP卷 第一千六百零一章  大战来临！
# 成功保存到: E:\论文\代码\数据处理\data\data_1602.txt
# 正在爬取第 1603 章, URL: http://www.biqugewx.info/biquge/25300/55819933
# 正在爬取第 1603 章: VIP卷 第一千六百零二章 洞府之战！
# 成功保存到: E:\论文\代码\数据处理\data\data_1603.txt
# 正在爬取第 1604 章, URL: http://www.biqugewx.info/biquge/25300/55819934
# 正在爬取第 1604 章: VIP卷 第一千六百零三章   以一敌二
# 成功保存到: E:\论文\代码\数据处理\data\data_1604.txt
# 正在爬取第 1605 章, URL: http://www.biqugewx.info/biquge/25300/55819935
# 正在爬取第 1605 章: VIP卷 第一千六百零四章   洞府出现
# 成功保存到: E:\论文\代码\数据处理\data\data_1605.txt
# 正在爬取第 1606 章, URL: http://www.biqugewx.info/biquge/25300/55819936
# 正在爬取第 1606 章: VIP卷 第一千六百零五章   危机关头
# 成功保存到: E:\论文\代码\数据处理\data\data_1606.txt
# 正在爬取第 1607 章, URL: http://www.biqugewx.info/biquge/25300/55819937
# 正在爬取第 1607 章: VIP卷 第一千六百零六章  老龙皇
# 成功保存到: E:\论文\代码\数据处理\data\data_1607.txt
# 正在爬取第 1608 章, URL: http://www.biqugewx.info/biquge/25300/55819938
# 正在爬取第 1608 章: VIP卷 第一千六百零七章   古帝洞府开启
# 成功保存到: E:\论文\代码\数据处理\data\data_1608.txt
# 正在爬取第 1609 章, URL: http://www.biqugewx.info/biquge/25300/55819939
# 正在爬取第 1609 章: VIP卷 第一千六百零八章   异火广场
# 成功保存到: E:\论文\代码\数据处理\data\data_1609.txt
# 正在爬取第 1610 章, URL: http://www.biqugewx.info/biquge/25300/55819940
# 正在爬取第 1610 章: VIP卷 第一千六百零九章  恐怖的帝品雏丹
# 成功保存到: E:\论文\代码\数据处理\data\data_1610.txt
# 正在爬取第 1611 章, URL: http://www.biqugewx.info/biquge/25300/55819941
# 正在爬取第 1611 章: VIP卷 第一千六百一十章  抢夺帝品雏丹
# 成功保存到: E:\论文\代码\数据处理\data\data_1611.txt
# 正在爬取第 1612 章, URL: http://www.biqugewx.info/biquge/25300/55819942
# 正在爬取第 1612 章: VIP卷 第一千六百一十一章  失手
# 成功保存到: E:\论文\代码\数据处理\data\data_1612.txt
# 正在爬取第 1613 章, URL: http://www.biqugewx.info/biquge/25300/55819943
# 正在爬取第 1613 章: VIP卷 第一千六百一十二章 魂天帝的野心
# 成功保存到: E:\论文\代码\数据处理\data\data_1613.txt
# 正在爬取第 1614 章, URL: http://www.biqugewx.info/biquge/25300/55819944
# 正在爬取第 1614 章: VIP卷 第一千六百一十三章 中州之难
# 成功保存到: E:\论文\代码\数据处理\data\data_1614.txt
# 正在爬取第 1615 章, URL: http://www.biqugewx.info/biquge/25300/55819945
# 正在爬取第 1615 章: VIP卷 第一千六百一十四章 异火榜第一！
# 成功保存到: E:\论文\代码\数据处理\data\data_1615.txt
# 正在爬取第 1616 章, URL: http://www.biqugewx.info/biquge/25300/55819946
# 正在爬取第 1616 章: VIP卷 第一千六百一十五章  帝之本源
# 成功保存到: E:\论文\代码\数据处理\data\data_1616.txt
# 正在爬取第 1617 章, URL: http://www.biqugewx.info/biquge/25300/55819947
# 正在爬取第 1617 章: VIP卷 第一千六百一十六章 古帝传承
# 成功保存到: E:\论文\代码\数据处理\data\data_1617.txt
# 正在爬取第 1618 章, URL: http://www.biqugewx.info/biquge/25300/55819948
# 正在爬取第 1618 章: VIP卷 第一千六百一十七章   源气
# 成功保存到: E:\论文\代码\数据处理\data\data_1618.txt
# 正在爬取第 1619 章, URL: http://www.biqugewx.info/biquge/25300/55819949
# 正在爬取第 1619 章: VIP卷 第一千六百一十八章  浩劫
# 成功保存到: E:\论文\代码\数据处理\data\data_1619.txt
# 正在爬取第 1620 章, URL: http://www.biqugewx.info/biquge/25300/55819950
# 正在爬取第 1620 章: VIP卷 第一千六百一十九章  魂帝，魂天帝！
# 成功保存到: E:\论文\代码\数据处理\data\data_1620.txt
# 正在爬取第 1621 章, URL: http://www.biqugewx.info/biquge/25300/55819951
# 正在爬取第 1621 章: VIP卷 两年三个月，五百三十万。
# 成功保存到: E:\论文\代码\数据处理\data\data_1621.txt
# 正在爬取第 1622 章, URL: http://www.biqugewx.info/biquge/25300/55819952
# 正在爬取第 1622 章: VIP卷 第一千六百二十章  斗帝强者的力量！
# 成功保存到: E:\论文\代码\数据处理\data\data_1622.txt
# 正在爬取第 1623 章, URL: http://www.biqugewx.info/biquge/25300/55819953
# 正在爬取第 1623 章: VIP卷 新书已发~~~
# 成功保存到: E:\论文\代码\数据处理\data\data_1623.txt
# 爬取完成！
